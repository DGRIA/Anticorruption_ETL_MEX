# %% [markdown]
# ## Análisis EDA: Asignación

# %% [markdown]
# ### Leyendo el dataset, convirtiéndolo a parquet y mostrando los primeros rows

# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
asignacion_df = pd.read_csv('../data/Cleaned/cleaned_asignacion_data.csv')
asignacion_df.to_parquet('../data/Cleaned/parquet_files/cleaned_asignacion_data.parquet')

# %%
asignacion_df = pd.read_parquet('../data/Cleaned/parquet_files/cleaned_asignacion_data.parquet')
asignacion_df.head()
# Out:
#    cve_expediente  cve_contrato  status  \
# 0          975480        964520  active
# 1         1016499       1019413  active
# 2         1004872       1025677  active
# 3         1036167       1043633  active
# 4         1057507       1070559  active
#
#                                    description_award  \
# 0  CONTRATO PLURIANUAL 2015 ¿ 2018, BAJO LA MODAL...
# 1  SERVICIO DE ATENCIÓN DE ASUNTOS LABORALES, REV...
# 2  MANTENIMIENTO PREVENTIVO Y CORRECTIVO DEL PARQ...
# 3                                               None
# 4  Servicios informáticos de adecuación, mantenim...
#
#                                          title_award  \
# 0  SERVICIO INTEGRAL DE ARRENDAMIENTO DE EQUIPO D...
# 1                     SERVICIOS DE ASESORÍA JURÍDICA
# 2  MANTENIMIENTO PREVENTIVO Y CORRECTIVO AL PARQU...
# 3                                   AGROASEMEX, S.A.
# 4  Servicios informáticos de adecuación, mantenim...
#
#          contract_start_date     contract_end_date  value_amount  \
# ...

# %%
print(asignacion_df.shape)
print(asignacion_df.info())
# Out:
# (828542, 19)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828542 entries, 0 to 828541
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   cve_expediente              828542 non-null  int64
#  1   cve_contrato                828542 non-null  int64
#  2   status                      826928 non-null  object
#  3   description_award           789388 non-null  object
#  4   title_award                 828541 non-null  object
#  5   contract_start_date         828542 non-null  object
#  6   contract_end_date           828316 non-null  object
#  7   value_amount                828542 non-null  float64
#  8   value_currency              828542 non-null  object
#  9   suppliers_id                828528 non-null  object
#  10  suppliers_name              828542 non-null  object
#  11  docs_url_awards             140262 non-null  object
# ...

# %% [markdown]
# Leyendo el dataset de licitación para hacer join y poder obtener algunas métricas

# %%
licitacion_df = pd.read_parquet('../data/Cleaned/parquet_files/cleaned_licitacion_data.parquet')
licitacion_df.head()
# Out:
#    cve_expediente procurementMethod procurementMethod_rationale    status  \
# 0          975480            direct             Art. 41 fr. III  complete
# 1          999514            direct             Art. 41 fr. VII  complete
# 2         1004872            direct     Art. 42 párrafo primero  complete
# 3         1016499            direct     Art. 42 párrafo segundo  complete
# 4         1036167            direct     Art. 42 párrafo primero  complete
#
#                                                title  \
# 0  SERVICIO INTEGRAL DE ARRENDAMIENTO DE EQUIPO D...
# 1  AA-019GYR026-E23-2016 SUMINISTRO E INSTALACION...
# 2  MANTENIMIENTO AL PARQUE VEHICULAR DE OFICINA C...
# 3                                   SERVICIO LEGALES
# 4  ASEGURAMIENTO DE BIENES MUEBLES E INMUEBLES DE...
#
#                                          description  has_enquiries  \
# 0  CONTRATO PLURIANUAL 2015 ¿ 2018, BAJO LA MODAL...          False
# ...

# %%
print(licitacion_df.shape)
print(licitacion_df.info())
# Out:
# (567053, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567053 entries, 0 to 567052
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   cve_expediente                567053 non-null  int64
#  1   procurementMethod             567014 non-null  object
#  2   procurementMethod_rationale   511716 non-null  object
#  3   status                        567053 non-null  object
#  4   title                         567053 non-null  object
#  5   description                   544355 non-null  object
#  6   has_enquiries                 567053 non-null  bool
#  7   number_tenderers              567053 non-null  int64
#  8   tender_start_date             567053 non-null  object
#  9   tender_end_date               91830 non-null   object
#  10  award_start_date              91830 non-null   object
#  11  award_end_date                566994 non-null  object
# ...

# %% [markdown]
# ### Preguntas de Negocio

# %% [markdown]
# ### 1. Para todos los tipos de procedimiento, porcentaje de contratos sin registro del tipo de moneda “value_currency”
