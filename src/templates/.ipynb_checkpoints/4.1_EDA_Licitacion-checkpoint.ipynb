# %% [markdown]
# ## Análisis EDA: Licitación

# %% [markdown]
# ### Leyendo el dataset, convirtiéndolo a parquet y mostrando los primeros rows

# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
licitacion_df = pd.read_csv('../data/Cleaned/cleaned_licitacion_data.csv')
licitacion_df.to_parquet('../data/Cleaned/parquet_files/cleaned_licitacion_data.parquet')

# %%
licitacion_df = pd.read_parquet('../data/Cleaned/parquet_files/cleaned_licitacion_data.parquet')
licitacion_df.head()
# Out:
#    cve_expediente procurementMethod procurementMethod_rationale    status  \
# 0          975480            direct             Art. 41 fr. III  complete
# 1          999514            direct             Art. 41 fr. VII  complete
# 2         1004872            direct     Art. 42 párrafo primero  complete
# 3         1016499            direct     Art. 42 párrafo segundo  complete
# 4         1036167            direct     Art. 42 párrafo primero  complete
#
#                                                title  \
# 0  SERVICIO INTEGRAL DE ARRENDAMIENTO DE EQUIPO D...
# 1  AA-019GYR026-E23-2016 SUMINISTRO E INSTALACION...
# 2  MANTENIMIENTO AL PARQUE VEHICULAR DE OFICINA C...
# 3                                   SERVICIO LEGALES
# 4  ASEGURAMIENTO DE BIENES MUEBLES E INMUEBLES DE...
#
#                                          description  has_enquiries  \
# 0  CONTRATO PLURIANUAL 2015 ¿ 2018, BAJO LA MODAL...          False
# 1                                               None          False
# 2  MANTENIMIENTOPREVENTIVO Y CORRECTIVO AL PARQUE...          False
# 3  SERVICIO DE ASUNTOS LABORALES, REVISIÓN JURÍDI...          False
# 4                                               None          False
#
#    number_tenderers     tender_start_date tender_end_date award_start_date  \
# 0                 0  2015-12-29T21:21:00Z            None             None
# 1                 5  2016-02-12T13:34:00Z            None             None
# 2                 6  2016-02-22T13:31:00Z            None             None
# 3                 0  2016-03-08T12:18:00Z            None             None
# 4                 0  2016-05-09T14:00:00Z            None             None
#
#               award_end_date    enquiry_start_date enquiry_end_date  \
# 0  2015-05-25 00:00:00+00:00  2015-12-29T21:21:00Z             None
# 1  2016-02-17 00:00:00+00:00  2016-02-12T13:34:00Z             None
# 2  2016-02-25 00:00:00+00:00  2016-02-22T13:31:00Z             None
# 3  2015-12-29 00:00:00+00:00  2016-03-08T12:18:00Z             None
# 4  2016-02-23 00:00:00+00:00  2016-05-09T14:00:00Z             None
#
#       procuring_entity_id                              procuring_entity_name  \
# 0  AGN120124321-047EZN999         AGN-Dirección de Administración #047EZN999
# 1  IMS421231I45-050GYR026  IMSS-Coordinación de abastecimiento y equipami...
# 2  LlC960821M84-008VST977  LICONSA-Gerencia de Recursos Materiales y Serv...
# 3  LlC960821M84-008VST977  LICONSA-Gerencia de Recursos Materiales y Serv...
# 4  IAA6210025R4-006A00996  INDAABIN-Unidad de Administración y Finanzas #...
#
#   value_currency_tender  value_amount_tender award_criteria  \
# 0                  None                  NaN           None
# 1                  None                  NaN           None
# 2                  None                  NaN           None
# 3                  None                  NaN           None
# 4                  None                  NaN           None
#
#   framework_agreement framework_agreement_platform framework_agreement_title  \
# 0                None                         None                      None
# 1                None                         None                      None
# 2                None                         None                      None
# 3                None                         None                      None
# 4                None                         None                      None
#
#       submission_method
# 0  electronicSubmission
# 1  electronicSubmission
# 2  electronicSubmission
# 3              inPerson
# 4              inPerson

# %%
licitacion_df.shape
# Out:
# (567053, 23)

# %%
licitacion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567053 entries, 0 to 567052
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   cve_expediente                567053 non-null  int64
#  1   procurementMethod             567014 non-null  object
#  2   procurementMethod_rationale   511716 non-null  object
#  3   status                        567053 non-null  object
#  4   title                         567053 non-null  object
#  5   description                   544355 non-null  object
#  6   has_enquiries                 567053 non-null  bool
#  7   number_tenderers              567053 non-null  int64
#  8   tender_start_date             567053 non-null  object
#  9   tender_end_date               91830 non-null   object
#  10  award_start_date              91830 non-null   object
#  11  award_end_date                566994 non-null  object
#  12  enquiry_start_date            567053 non-null  object
#  13  enquiry_end_date              67455 non-null   object
#  14  procuring_entity_id           567052 non-null  object
#  15  procuring_entity_name         567052 non-null  object
#  16  value_currency_tender         70988 non-null   object
#  17  value_amount_tender           9451 non-null    float64
#  18  award_criteria                91781 non-null   object
#  19  framework_agreement           3903 non-null    object
#  20  framework_agreement_platform  3903 non-null    object
#  21  framework_agreement_title     3903 non-null    object
#  22  submission_method             567051 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(19)
# memory usage: 95.7+ MB

# %% [markdown]
# ### Preguntas de Negocio

# %% [markdown]
# ### 1. ¿Cuántos expedientes por tipo de moneda?

# %%
# Count expedientes by currency type, including None values
currency_counts = licitacion_df['value_currency_tender'].value_counts(dropna=False)
currency_counts.index = currency_counts.index.fillna('None')
print(currency_counts)

# Plot the distribution of expedientes by currency type, including None values
plt.figure(figsize=(10, 6))
currency_counts.plot(kind='bar', color='red')
plt.xlabel('Tipo de Moneda')
plt.ylabel('Numero de expedientes')
plt.title('Numero de Expedientes por tipo de moneda')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# value_currency_tender
# None    496065
# MXN      70804
# USD        169
# TEST        15
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Para todos los tipos de procedimiento, el porcentaje de registros para cada tipo de estatus

# %%
# Calculate percentage of each status for every procurement method
status_percentage = licitacion_df.groupby('procurementMethod')['status'].value_counts(normalize=True).unstack().fillna(0) * 100
print(status_percentage)

# Plot the percentage of each status for every procurement method
status_percentage.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='viridis')
plt.xlabel('Procurement Method')
plt.ylabel('Percentage')
plt.title('Percentage of Records by Status for Each Procurement Method')
plt.legend(title='Status', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# status               active   complete  unsuccessful
# procurementMethod
# direct             0.003577  99.991795      0.004628
# open               8.239592  77.936123     13.824285
# selective          7.305748  76.393010     16.301242

# %% [markdown]
# ### 3. Para tipos de procedimiento selective y open, el porcentaje de información sin valor en “number_tenderers”

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter for procurement methods 'selective' and 'open'
filtered_df = licitacion_df[licitacion_df['procurementMethod'].isin(['selective', 'open'])]

# Calculate the percentages
total_count = filtered_df.shape[0]
zero_tenderers_count = filtered_df[filtered_df['number_tenderers'] == 0].shape[0]
non_zero_tenderers_count = filtered_df[filtered_df['number_tenderers'] != 0].shape[0]

zero_tenderers_percentage = (zero_tenderers_count / total_count) * 100
non_zero_tenderers_percentage = (non_zero_tenderers_count / total_count) * 100

print(f"Percentage of records with 'number_tenderers' = 0: {zero_tenderers_percentage:.2f}%")
print(f"Percentage of records with 'number_tenderers' != 0: {non_zero_tenderers_percentage:.2f}%")

# Plotting the percentages
plt.figure(figsize=(8, 5))
plt.bar(['0 Tenderers', 'Non-0 Tenderers'], [zero_tenderers_percentage, non_zero_tenderers_percentage], color=['red', 'green'])
plt.xlabel('Numero de Tenderers')
plt.ylabel('Porcentaje')
plt.title("Porcentaje de registros por Numero de Tenderers para 'selective' and 'open' Procurement Methods")
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Annotating the bars with the percentage values
for index, value in enumerate([zero_tenderers_percentage, non_zero_tenderers_percentage]):
    plt.text(index, value + 1, f"{value:.2f}%", ha='center')

plt.show()
# Out:
# Percentage of records with 'number_tenderers' = 0: 20.59%
# Percentage of records with 'number_tenderers' != 0: 79.41%

# %% [markdown]
# #### 4. Para procedimientos de adjudicación directa, el porcentaje de información sin valor en “procurementMethod_rationale”

# %%
# Filter for procurement method 'direct'
direct_df = licitacion_df[licitacion_df['procurementMethod'] == 'direct']

# Calculate the percentage of missing or empty values in 'procurementMethod_rationale'
missing_rationale_percentage = (direct_df['procurementMethod_rationale'].isna() | (direct_df['procurementMethod_rationale'] == '')).mean() * 100
print(f"Percentage of missing or empty 'procurementMethod_rationale': {missing_rationale_percentage:.2f}%")

# Visualize the percentage of missing or empty values in 'procurementMethod_rationale'
plt.figure(figsize=(6, 4))
plt.bar(['Missing or Empty', 'Non-Missing'], [missing_rationale_percentage, 100 - missing_rationale_percentage], color=['red', 'green'])
plt.xlabel('Procurement Method Rationale')
plt.ylabel('Porcentaje')
plt.title("Porcentaje de valores nulos o faltantes en 'procurementMethod_rationale' para 'direct' Procurement Method")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Percentage of missing or empty 'procurementMethod_rationale': 0.00%
