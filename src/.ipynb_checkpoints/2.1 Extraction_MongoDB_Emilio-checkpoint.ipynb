# %% [markdown]
# # Lectura al MongoDB
#
# El objetivo de este Jupyter notebook es: i) verificar que la base de datos MongoDB está correctamente instalada y podemos hacer una lectura correcta de los datos; y ii) Extraer la tablas mencionadas en el punto 4 y guardar los datos en formato .csv.
#
# En este notebook ejecutaremos los siguientes test:
# 1. Conexión a la base de datos MongoDB en local.
# 2. Revisar el tamaño y la última actualización de los datos.
# 3. Crear una muestra pequeña de datos para confirmar que los comandos funcionan.
# 4. Crear las tablas solicitadas en el diagrama ER con una muestra de los datos.

# %%
# Importa las librerías
from pymongo import MongoClient
import pandas as pd

# %% [markdown]
# ## 1. Conexión a la base de datos MongoDB en local.
#
# Antes de ejecutar este notebook acuérdate de arrancar la base de datos MongoDB. Se recomienda utilizar Mongo Compass para una gestión más intuitiva de la base de datos.

# %%
# Reemplaza 'localhost' con la dirección de tu servidor MongoDB si es diferente
# y '27017' con el puerto correspondiente si has configurado uno distinto.
client = MongoClient('mongodb://localhost:27017/')

#Nombre las bases de datos
db = client['Contratos_EDCA']

# Obtén una colección para verificar la conexión
try:
    # Reemplaza 'Contratos_EDCA' con el nombre de una colección existente en tu base de datos
    colecciones = db.list_collection_names()  # Lista todas las colecciones para verificar la conexión
    if 'Contratos_EDCA_Sample' in colecciones:
        print("Conexión exitosa a la base de datos y la colección encontrada.")
    else:
        print("Conexión exitosa a la base de datos, pero la colección no fue encontrada.")
except Exception as e:
    print(f"Error al conectar a la base de datos: {e}")


# Listar todas las bases de datos
databases = client.list_database_names()
collections = db.list_collection_names()

# Imprimir la lista de bases de datos
print("Bases de datos disponibles son:", databases)

print("\n")

print("Colecciones dentro de la base de datos:", collections)
# Out:
# Conexión exitosa a la base de datos y la colección encontrada.
# Bases de datos disponibles son: ['Contratos_EDCA', 'admin', 'config', 'local']
#
#
# Colecciones dentro de la base de datos: ['Contratos_EDCA_Sample']

# %% [markdown]
# ## 2. Revisar el tamaño y la última actualización de los datos.
#
# La base de datos Contrataciones tiene dos colecciones:
# - Contratos_EDCA: 7 GB
# - Sample_Contratos_EDCA: 800 MB

# %%
## NO CORRER ESTE CHUNK SI NO ES NECESARIO ##

# Imprimir el tamaño de la base de datos, número de colecciones y última actualización

# Obteniendo el tamaño de la base de datos en GB
print(f"Obteniendo el tamaño de la base de datos.")
db_stats = db.command("dbstats")
db_size_gb = db_stats['storageSize'] / (1024**3)  # Convertir bytes a GB
print(f"Tamaño de la base de datos: {db_size_gb} GB")

# Obteniendo el número de documentos en la colección 'Contratos_EDCA'
print(f"Obteniendo el número de documentos. Este proceso puede tardar hasta 3 minutos...")
num_documents = db['Contratos_EDCA_Sample'].count_documents({})
print(f"Número de documentos en la colección 'Contratos_EDCA_Sample': {num_documents}")
# Out:
# Obteniendo el tamaño de la base de datos.
# Tamaño de la base de datos: 0.7626686096191406 GB
# Obteniendo el número de documentos. Este proceso puede tardar hasta 3 minutos...
# Número de documentos en la colección 'Contratos_EDCA_Sample': 137113

# %% [markdown]
# ## 3. Crear una muestra pequeña de datos para confirmar que los comandos funcionan.
#
# Ejecuta esto sólo si la muestra no ha sido creada.
#
# Guardaremos la nueva muestra _Sample_Contratos_EDCA_ en una nueva colección.

# %%
## NO CORRER ESTE CHUNK SI NO ES NECESARIO ##

# Generando la muestra aleatoria y guardándola en una nueva colección
sample_size = int(num_documents * 0.05)  # Calcula el 5% del total de documentos
print(f"Número de documentos en la muestra aleatoria es: {sample_size}")

# Realiza la agregación para obtener la muestra aleatoria
sample = db['Contratos_EDCA'].aggregate([
    { '$sample': { 'size': sample_size } }
])
sample_documents = list(sample)
print(f"Sample creado")

# Guarda la muestra en una nueva colección
db['Sample_Contratos_EDCA'].insert_many(sample_documents)
print(f"Muestra guardada en la colección 'Sample_Contratos_EDCA'!")

# %% [markdown]
# ## 4. Crear las tablas solicitadas en el diagrama ER con una muestra de los datos.
#
# Extrae las siguientes tablas de la muestra de la base de datos:
#
# - Participantes_Proveedores (Parties)
# - Licitacion (Tender)
# - asignacion (Awards)
# - comprador (Parties + Buyer)
# - documentos_tender (Tender)
# - items_adq (Awards)
# - items_tender (Tender)
#
# _Tener en cuenta que sólo estamos extrayendo los 20 primeros registros para propósitos demostrativos._

# %% [markdown]
# ### 4.1 Participantes_Proveedores (Origen: Parties)

# %%
# Consulta actualizada a la base de datos Contratos_EDCA
consulta_actualizada = db['Contratos_EDCA_Sample'].find({}, {})

# Creando una lista de diccionarios para facilitar la creación del dataframe
datos = []
for contrato in consulta_actualizada:
    contrato_dict = {
        'cve_expediente': '',
        'cve_contrato': '',
        'identifier_id': '',
        'roles': '',
        'name': '',
        'identifier_legalname': '',
        'identifier_scheme': '',
        'identifier_uri': '',
        'address_country_name': '',
        'address_locality': '',
        'address_postalcode': '',
        'address_region': '',
        'address_streetAddress': '',
        'contact_point_email': '',
        'contact_point_name': '',
        'contact_point_telephone': ''
    }
    try:
        contrato_dict['cve_expediente'] = contrato.get('releases', [{}])[0].get('tender', {}).get('id', '') #id
        contrato_dict['cve_contrato'] = contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', '') #award id
        contrato_dict['identifier_id'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('identifier', {}).get('id', '')
        contrato_dict['roles'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('roles', [{}])[0]
        contrato_dict['name'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('name', '')
        contrato_dict['identifier_legalname'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('identifier', {}).get('legalName', '')
        contrato_dict['identifier_scheme'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('identifier', {}).get('scheme', '')
        contrato_dict['identifier_uri'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('identifier', {}).get('uri', '')
        contrato_dict['address_country_name'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', {}).get('countryName', '')
        contrato_dict['address_locality'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', {}).get('locality', '')
        contrato_dict['address_postalcode'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', {}).get('postalCode', '')
        contrato_dict['address_region'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', {}).get('region', '')
        contrato_dict['address_streetAddress'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', {}).get('streetAddress', '')
        contrato_dict['contact_point_email'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('contactPoint', {}).get('email', '')
        contrato_dict['contact_point_name'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('contactPoint', {}).get('name', '')
        contrato_dict['contact_point_telephone'] = contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('contactPoint', {}).get('telephone', '')
    except AttributeError:
        pass
    datos.append(contrato_dict)

# Creando el dataframe de Participantes_Proveedores
df_participantes_proveedores = pd.DataFrame(datos)

# Exportando el dataframe a un archivo csv
df_participantes_proveedores.to_csv('../data/Processed/participantes_proveedores_v2.csv', index=False)
print("Proceso terminado. \n     El dataset de Participantes_Proveedores tiene el siguiente tamaño: (files x columnas)")

print(df_participantes_proveedores.shape)
# Out:
# Proceso terminado.
#      El dataset de Participantes_Proveedores tiene el siguiente tamaño: (files x columnas)
# (137113, 16)

# %% [markdown]
# #### 4.2 Licitación (Origen: Tender)

# %%
# Consulta actualizada a la base de datos Contratos_EDCA
consulta_actualizada = db['Contratos_EDCA_Sample'].find({}, {})

# Creando una lista de diccionarios para facilitar la creación del dataframe
datos = []
for contrato in consulta_actualizada:
    contrato_dict = {
        'cve_expediente': '',
        'procurementMethod': '',
        'procurementMethod_rationale': '',
        'status': '',
        'description': '',
        'has_enquiries': '',
        'tender_start_date': '',
        'tender_end_date': '',
        'award_start_date': '',
        'award_end_date': '',
        'enquiry_start_date': '',
        'enquiry_end_date': '',
        'procuring_entity_id': '',
        'procuring_entity_name': '',
        'value_currency_tender': '',
        'value_amount_tender': '',
        'award_criteria': '',
        'framework_agreement': '',
        'framework_agreement_platform': '',
        'framework_agreement_title': '',
    }
    try:
        contrato_dict['cve_expediente'] = contrato.get('releases', [{}])[0].get('tender', {}).get('id', '') #id
        contrato_dict['procurementMethod_rationale'] = contrato.get('releases', [{}])[0].get('tender', {}).get('procurementMethod', '') #id,
        contrato_dict['status'] = contrato.get('releases', [{}])[0].get('tender', {}).get('status', 'NA'),
        contrato_dict['description'] = contrato.get('releases', [{}])[0].get('tender', {}).get('description', 'NA'),
        contrato_dict['has_enquiries'] =   contrato.get('releases', [{}])[0].get('tender', {}).get('hasEnquiries', 'NA'),
        contrato_dict['tender_start_date'] =    contrato.get('releases', [{}])[0].get('tender', {}).get('tenderPeriod', [{}]).get('startDate', 'NA'),
        contrato_dict['tender_end_date'] = contrato.get('releases', [{}])[0].get('tender', {}).get('tenderPeriod', [{}]).get('endDate', 'NA'),
        contrato_dict['award_start_date'] = contrato.get('releases', [{}])[0].get('tender', {}).get('awardPeriod', [{}]).get('startDate', 'NA'),
        contrato_dict['award_end_date'] =   contrato.get('releases', [{}])[0].get('tender', {}).get('awardPeriod', [{}]).get('endDate', 'NA'),
        contrato_dict['enquiry_start_date'] =    contrato.get('releases', [{}])[0].get('tender', {}).get('enquiryPeriod', [{}]).get('startDate', 'NA'),
        contrato_dict['enquiry_end_date'] =   contrato.get('releases', [{}])[0].get('tender', {}).get('enquiryPeriod', [{}]).get('endDate', 'NA'),
        contrato_dict['procuring_entity_id'] =  contrato.get('releases', [{}])[0].get('tender', {}).get('procuringEntity', [{}]).get('id', 'NA'), # No está en el esquema
        contrato_dict['procuring_entity_name'] =   contrato.get('releases', [{}])[0].get('tender', {}).get('procuringEntity', [{}]).get('name', 'NA'), # No está en el esquema
        contrato_dict['value_currency_tender'] =    contrato.get('releases', [{}])[0].get('tender', {}).get('value', [{}]).get('currency', 'NA'),
        contrato_dict['value_amount_tender'] =  contrato.get('releases', [{}])[0].get('tender', {}).get('value', [{}]).get('amount', 'NA'),
        contrato_dict['award_criteria'] =  contrato.get('releases', [{}])[0].get('tender', {}).get('awardCriteria', 'NA'),
        contrato_dict['framework_agreement'] =  contrato.get('releases', [{}])[0].get('tender', {}).get('frameworkAgreement', 'NA'), # Este es valorr binario
        contrato_dict['framework_agreement_platform'] = contrato.get('releases', [{}])[0].get('tender', {}).get('frameworkAgreementPlatform', 'NA'),
        contrato_dict['framework_agreement_title'] =  contrato.get('releases', [{}])[0].get('tender', {}).get('frameworkAgreementTitle', 'NA'),
           
    except AttributeError:
        pass
    datos.append(contrato_dict)

# Creando el dataframe de Participantes_Proveedores
df_licitacion = pd.DataFrame(datos)

# Exportando el dataframe a un archivo csv
df_licitacion.to_csv('../data/Processed/licitacion_v2.csv', index=False)
print("Proceso terminado. \n     El dataset de Participantes_Proveedores tiene el siguiente tamaño: (files x columnas)")

print(df_licitacion.shape)
# Out:
# Proceso terminado.
#      El dataset de Participantes_Proveedores tiene el siguiente tamaño: (files x columnas)
# (137113, 20)

# %% [markdown]
# ## 4.3 Asignación (awards)
#
# ** **FALTAN LAS VARIABLES DOCS** **

# %%
# Consulta actualizada a la base de datos Contratos_EDCA
consulta_actualizada = db['Contratos_EDCA_Sample'].find({}, {})

# Creando una lista de diccionarios para facilitar la creación del dataframe
datos = []
Bugs = []
for contrato in consulta_actualizada:
    try:
        contrato_dict = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            'cve_contrato': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'), #award id
            'status': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('status', 'NA'),
            'description_award': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('description', 'NA'),
            'title_award': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('title', 'NA'),
            #'contract_start_date': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'),
            #'contract_end_date': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'),
            'value_amount': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('value', [{}]).get('amount', 'NA'),
            'value_currency': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('value', [{}]).get('currency', 'NA'),
            'suppliers_id': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('suppliers', [{}])[0].get('id', 'NA'),
        }
        #print(contrato_dict['cve_expediente'])
        datos.append(contrato_dict)
    except AttributeError:
        Error = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            'cve_contrato': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'), #award id
        }
        Bugs.append(Error)
        print(f"Error: se intentó acceder a un atributo de un objeto no válido. {contrato_dict['cve_expediente']}")

# Creando el dataframe de Parties y Errores
df_participantes_proveedores = pd.DataFrame(datos)
df_Err_participantes_proveedores = pd.DataFrame(Bugs)

# Exportando el dataframe a un archivo csv
df_participantes_proveedores.to_csv('../data/Processed/participantes_proveedores.csv', index=False)
df_Err_participantes_proveedores.to_csv('../data/Processed/participantes_proveedores_Errors.csv', index=False)
print("Proceso terminado. \n     El dataset de Participantes_Proveedores tiene el siguiente tamaño: (files x columnas)")

print(df_participantes_proveedores.shape)
print(f"\n\nSe ha registrado los siguientes registros con errores: {df_Err_participantes_proveedores.shape[0]}")
# Out:
# Error: se intentó acceder a un atributo de un objeto no válido. 2416049
# Error: se intentó acceder a un atributo de un objeto no válido. 2450533
# Error: se intentó acceder a un atributo de un objeto no válido. 2491118
# Error: se intentó acceder a un atributo de un objeto no válido. 2244435
# Error: se intentó acceder a un atributo de un objeto no válido. 2403311
# Error: se intentó acceder a un atributo de un objeto no válido. 2490541
# Error: se intentó acceder a un atributo de un objeto no válido. 2322653
# Error: se intentó acceder a un atributo de un objeto no válido. 2488062
# Error: se intentó acceder a un atributo de un objeto no válido. 2377091
# Error: se intentó acceder a un atributo de un objeto no válido. 2474638
# Error: se intentó acceder a un atributo de un objeto no válido. 2335439
# Error: se intentó acceder a un atributo de un objeto no válido. 2325247
# Error: se intentó acceder a un atributo de un objeto no válido. 2350177
# Error: se intentó acceder a un atributo de un objeto no válido. 2359723
# Error: se intentó acceder a un atributo de un objeto no válido. 2478807
# Error: se intentó acceder a un atributo de un objeto no válido. 2415751
# Error: se intentó acceder a un atributo de un objeto no válido. 2415751
# Error: se intentó acceder a un atributo de un objeto no válido. 2355699
# Error: se intentó acceder a un atributo de un objeto no válido. 2459158
# Error: se intentó acceder a un atributo de un objeto no válido. 2438006
# Error: se intentó acceder a un atributo de un objeto no válido. 2336141
# Error: se intentó acceder a un atributo de un objeto no válido. 2340836
# Error: se intentó acceder a un atributo de un objeto no válido. 2321656
# Error: se intentó acceder a un atributo de un objeto no válido. 2337610
# Error: se intentó acceder a un atributo de un objeto no válido. 2337610
# Error: se intentó acceder a un atributo de un objeto no válido. 2334277
# Error: se intentó acceder a un atributo de un objeto no válido. 2383811
# Error: se intentó acceder a un atributo de un objeto no válido. 2405888
# Error: se intentó acceder a un atributo de un objeto no válido. 2476716
# Error: se intentó acceder a un atributo de un objeto no válido. 2434205
# Error: se intentó acceder a un atributo de un objeto no válido. 2318740
# Error: se intentó acceder a un atributo de un objeto no válido. 2318740
# Error: se intentó acceder a un atributo de un objeto no válido. 2318920
# Error: se intentó acceder a un atributo de un objeto no válido. 2393318
# Error: se intentó acceder a un atributo de un objeto no válido. 2077751
# Error: se intentó acceder a un atributo de un objeto no válido. 2516060
# Error: se intentó acceder a un atributo de un objeto no válido. 2466407
# Error: se intentó acceder a un atributo de un objeto no válido. 2356441
# Error: se intentó acceder a un atributo de un objeto no válido. 2483293
# Error: se intentó acceder a un atributo de un objeto no válido. 2336064
# Error: se intentó acceder a un atributo de un objeto no válido. 2345358
# Error: se intentó acceder a un atributo de un objeto no válido. 2507557
# Error: se intentó acceder a un atributo de un objeto no válido. 2374907
# Error: se intentó acceder a un atributo de un objeto no válido. 2449699
# Error: se intentó acceder a un atributo de un objeto no válido. 2352335
# Error: se intentó acceder a un atributo de un objeto no válido. 2402920
# Error: se intentó acceder a un atributo de un objeto no válido. 2461081
# Error: se intentó acceder a un atributo de un objeto no válido. 2348925
# Error: se intentó acceder a un atributo de un objeto no válido. 1609683
# Error: se intentó acceder a un atributo de un objeto no válido. 1609683
# Error: se intentó acceder a un atributo de un objeto no válido. 2343145
# Error: se intentó acceder a un atributo de un objeto no válido. 2484127
# Error: se intentó acceder a un atributo de un objeto no válido. 2381765
# Error: se intentó acceder a un atributo de un objeto no válido. 2417427
# Error: se intentó acceder a un atributo de un objeto no válido. 2325296
# Error: se intentó acceder a un atributo de un objeto no válido. 2365183
# Error: se intentó acceder a un atributo de un objeto no válido. 1661715
# Error: se intentó acceder a un atributo de un objeto no válido. 2306254
# Error: se intentó acceder a un atributo de un objeto no válido. 2376960
# Error: se intentó acceder a un atributo de un objeto no válido. 2326725
# Error: se intentó acceder a un atributo de un objeto no válido. 2402835
# Error: se intentó acceder a un atributo de un objeto no válido. 2328124
# Error: se intentó acceder a un atributo de un objeto no válido. 2405779
# Error: se intentó acceder a un atributo de un objeto no válido. 2401851
# Error: se intentó acceder a un atributo de un objeto no válido. 2401851
# Error: se intentó acceder a un atributo de un objeto no válido. 2417513
# Error: se intentó acceder a un atributo de un objeto no válido. 2442772
# Error: se intentó acceder a un atributo de un objeto no válido. 2321386
# Error: se intentó acceder a un atributo de un objeto no válido. 2329846
# Error: se intentó acceder a un atributo de un objeto no válido. 2414767
# Error: se intentó acceder a un atributo de un objeto no válido. 2477617
# Error: se intentó acceder a un atributo de un objeto no válido. 2344523
# Error: se intentó acceder a un atributo de un objeto no válido. 2304693
# Error: se intentó acceder a un atributo de un objeto no válido. 2304693
# Error: se intentó acceder a un atributo de un objeto no válido. 2320575
# Error: se intentó acceder a un atributo de un objeto no válido. 2452990
# Error: se intentó acceder a un atributo de un objeto no válido. 2310901
# Error: se intentó acceder a un atributo de un objeto no válido. 2322268
# Error: se intentó acceder a un atributo de un objeto no válido. 2428001
# Error: se intentó acceder a un atributo de un objeto no válido. 2428001
# Error: se intentó acceder a un atributo de un objeto no válido. 2477159
# Error: se intentó acceder a un atributo de un objeto no válido. 2407118
# Error: se intentó acceder a un atributo de un objeto no válido. 2393410
# Error: se intentó acceder a un atributo de un objeto no válido. 2312830
# Error: se intentó acceder a un atributo de un objeto no válido. 1840221
# Error: se intentó acceder a un atributo de un objeto no válido. 2336288
# Error: se intentó acceder a un atributo de un objeto no válido. 2482083
# Error: se intentó acceder a un atributo de un objeto no válido. 2457008
# Error: se intentó acceder a un atributo de un objeto no válido. 2342291
# Error: se intentó acceder a un atributo de un objeto no válido. 2410812
# Error: se intentó acceder a un atributo de un objeto no válido. 2410812
# Error: se intentó acceder a un atributo de un objeto no válido. 2516570
# Error: se intentó acceder a un atributo de un objeto no válido. 2402793
# Error: se intentó acceder a un atributo de un objeto no válido. 2409821
# Error: se intentó acceder a un atributo de un objeto no válido. 2365922
# Error: se intentó acceder a un atributo de un objeto no válido. 2307485
# Error: se intentó acceder a un atributo de un objeto no válido. 2428177
# Error: se intentó acceder a un atributo de un objeto no válido. 2447517
# Error: se intentó acceder a un atributo de un objeto no válido. 2405615
# Error: se intentó acceder a un atributo de un objeto no válido. 2386192
# Error: se intentó acceder a un atributo de un objeto no válido. 2341064
# Error: se intentó acceder a un atributo de un objeto no válido. 2409225
# Error: se intentó acceder a un atributo de un objeto no válido. 2493859
# Error: se intentó acceder a un atributo de un objeto no válido. 2368959
# Error: se intentó acceder a un atributo de un objeto no válido. 2338063
# Error: se intentó acceder a un atributo de un objeto no válido. 2349340
# Error: se intentó acceder a un atributo de un objeto no válido. 2318327
# Error: se intentó acceder a un atributo de un objeto no válido. 2318327
# Error: se intentó acceder a un atributo de un objeto no válido. 2342061
# Error: se intentó acceder a un atributo de un objeto no válido. 2347296
# Error: se intentó acceder a un atributo de un objeto no válido. 2266604
# Error: se intentó acceder a un atributo de un objeto no válido. 1990626
# Error: se intentó acceder a un atributo de un objeto no válido. 2235746
# Error: se intentó acceder a un atributo de un objeto no válido. 2458924
# Error: se intentó acceder a un atributo de un objeto no válido. 2444807
# Error: se intentó acceder a un atributo de un objeto no válido. 2349400
# Error: se intentó acceder a un atributo de un objeto no válido. 1924066
# Error: se intentó acceder a un atributo de un objeto no válido. 2456617
# Error: se intentó acceder a un atributo de un objeto no válido. 2370967
# Error: se intentó acceder a un atributo de un objeto no válido. 2367479
# Error: se intentó acceder a un atributo de un objeto no válido. 2462636
# Error: se intentó acceder a un atributo de un objeto no válido. 2388537
# Error: se intentó acceder a un atributo de un objeto no válido. 2040433
# Error: se intentó acceder a un atributo de un objeto no válido. 2443650
# Error: se intentó acceder a un atributo de un objeto no válido. 2378754
# Error: se intentó acceder a un atributo de un objeto no válido. 2393231
# Error: se intentó acceder a un atributo de un objeto no válido. 2093904
# Error: se intentó acceder a un atributo de un objeto no válido. 2484098
# Error: se intentó acceder a un atributo de un objeto no válido. 2461216
# Error: se intentó acceder a un atributo de un objeto no válido. 2308392
# Error: se intentó acceder a un atributo de un objeto no válido. 2357020
# Error: se intentó acceder a un atributo de un objeto no válido. 2358716
# Error: se intentó acceder a un atributo de un objeto no válido. 2334521
# Error: se intentó acceder a un atributo de un objeto no válido. 2405937
# Error: se intentó acceder a un atributo de un objeto no válido. 2405937
# Error: se intentó acceder a un atributo de un objeto no válido. 2307871
# Error: se intentó acceder a un atributo de un objeto no válido. 2375319
# Error: se intentó acceder a un atributo de un objeto no válido. 2399199
# Error: se intentó acceder a un atributo de un objeto no válido. 2398853
# Error: se intentó acceder a un atributo de un objeto no válido. 2454963
# Error: se intentó acceder a un atributo de un objeto no válido. 2368608
# Error: se intentó acceder a un atributo de un objeto no válido. 2348330
# Error: se intentó acceder a un atributo de un objeto no válido. 2323971
# Error: se intentó acceder a un atributo de un objeto no válido. 2345311
# Error: se intentó acceder a un atributo de un objeto no válido. 2364095
# Error: se intentó acceder a un atributo de un objeto no válido. 2373796
# Error: se intentó acceder a un atributo de un objeto no válido. 1841943
# Error: se intentó acceder a un atributo de un objeto no válido. 2497387
# Error: se intentó acceder a un atributo de un objeto no válido. 2441105
# Error: se intentó acceder a un atributo de un objeto no válido. 2409514
# Error: se intentó acceder a un atributo de un objeto no válido. 2351734
# Error: se intentó acceder a un atributo de un objeto no válido. 2523416
# Error: se intentó acceder a un atributo de un objeto no válido. 2348815
# Error: se intentó acceder a un atributo de un objeto no válido. 1854621
# Error: se intentó acceder a un atributo de un objeto no válido. 2401874
# Error: se intentó acceder a un atributo de un objeto no válido. 2374455
# Error: se intentó acceder a un atributo de un objeto no válido. 2372393
# Error: se intentó acceder a un atributo de un objeto no válido. 1851472
# Error: se intentó acceder a un atributo de un objeto no válido. 2382798
# Error: se intentó acceder a un atributo de un objeto no válido. 2096473
# Error: se intentó acceder a un atributo de un objeto no válido. 2096473
# Error: se intentó acceder a un atributo de un objeto no válido. 2450043
# Error: se intentó acceder a un atributo de un objeto no válido. 2526282
# Error: se intentó acceder a un atributo de un objeto no válido. 1928759
# Error: se intentó acceder a un atributo de un objeto no válido. 2412285
# Error: se intentó acceder a un atributo de un objeto no válido. 2383323
# Error: se intentó acceder a un atributo de un objeto no válido. 2493558
# Error: se intentó acceder a un atributo de un objeto no válido. 1848523
# Error: se intentó acceder a un atributo de un objeto no válido. 1848523
# Error: se intentó acceder a un atributo de un objeto no válido. 2403542
# Error: se intentó acceder a un atributo de un objeto no válido. 2317786
# Error: se intentó acceder a un atributo de un objeto no válido. 2432903
# Error: se intentó acceder a un atributo de un objeto no válido. 2432903
# Error: se intentó acceder a un atributo de un objeto no válido. 2356007
# Error: se intentó acceder a un atributo de un objeto no válido. 2393977
# Error: se intentó acceder a un atributo de un objeto no válido. 2391892
# Error: se intentó acceder a un atributo de un objeto no válido. 2316868
# Error: se intentó acceder a un atributo de un objeto no válido. 2477691
# Error: se intentó acceder a un atributo de un objeto no válido. 2477630
# Error: se intentó acceder a un atributo de un objeto no válido. 2329775
# Error: se intentó acceder a un atributo de un objeto no válido. 2404392
# Error: se intentó acceder a un atributo de un objeto no válido. 2473519
# Error: se intentó acceder a un atributo de un objeto no válido. 2326361
# Error: se intentó acceder a un atributo de un objeto no válido. 2388852
# Error: se intentó acceder a un atributo de un objeto no válido. 2453488
# Error: se intentó acceder a un atributo de un objeto no válido. 2378908
# Error: se intentó acceder a un atributo de un objeto no válido. 2461404
# Error: se intentó acceder a un atributo de un objeto no válido. 2405440
# Error: se intentó acceder a un atributo de un objeto no válido. 1702179
# Error: se intentó acceder a un atributo de un objeto no válido. 2441735
# Error: se intentó acceder a un atributo de un objeto no válido. 2397930
# Error: se intentó acceder a un atributo de un objeto no válido. 2317117
# Error: se intentó acceder a un atributo de un objeto no válido. 2501781
# Error: se intentó acceder a un atributo de un objeto no válido. 2456180
# Error: se intentó acceder a un atributo de un objeto no válido. 2323619
# Error: se intentó acceder a un atributo de un objeto no válido. 2340133
# Error: se intentó acceder a un atributo de un objeto no válido. 2316878
# Error: se intentó acceder a un atributo de un objeto no válido. 2090236
# Error: se intentó acceder a un atributo de un objeto no válido. 2398697
# Error: se intentó acceder a un atributo de un objeto no válido. 1993638
# Error: se intentó acceder a un atributo de un objeto no válido. 2420260
# Error: se intentó acceder a un atributo de un objeto no válido. 2313427
# Error: se intentó acceder a un atributo de un objeto no válido. 2456111
# Error: se intentó acceder a un atributo de un objeto no válido. 1881845
# Error: se intentó acceder a un atributo de un objeto no válido. 2452719
# Error: se intentó acceder a un atributo de un objeto no válido. 2456503
# Error: se intentó acceder a un atributo de un objeto no válido. 2404221
# Error: se intentó acceder a un atributo de un objeto no válido. 2394997
# Error: se intentó acceder a un atributo de un objeto no válido. 2348987
# Error: se intentó acceder a un atributo de un objeto no válido. 2435561
# Error: se intentó acceder a un atributo de un objeto no válido. 2468527
# Error: se intentó acceder a un atributo de un objeto no válido. 2305139
# Error: se intentó acceder a un atributo de un objeto no válido. 2400357
# Error: se intentó acceder a un atributo de un objeto no válido. 2313325
# Error: se intentó acceder a un atributo de un objeto no válido. 2318917
# Error: se intentó acceder a un atributo de un objeto no válido. 2451356
# Error: se intentó acceder a un atributo de un objeto no válido. 2440677
# Error: se intentó acceder a un atributo de un objeto no válido. 2414888
# Error: se intentó acceder a un atributo de un objeto no válido. 2521411
# Error: se intentó acceder a un atributo de un objeto no válido. 2344159
# Error: se intentó acceder a un atributo de un objeto no válido. 2466801
# Error: se intentó acceder a un atributo de un objeto no válido. 2349708
# Error: se intentó acceder a un atributo de un objeto no válido. 2503520
# Error: se intentó acceder a un atributo de un objeto no válido. 2503520
# Error: se intentó acceder a un atributo de un objeto no válido. 1949419
# Error: se intentó acceder a un atributo de un objeto no válido. 2297635
# Error: se intentó acceder a un atributo de un objeto no válido. 2472263
# Error: se intentó acceder a un atributo de un objeto no válido. 2444907
# Error: se intentó acceder a un atributo de un objeto no válido. 2316457
# Error: se intentó acceder a un atributo de un objeto no válido. 2416229
# Error: se intentó acceder a un atributo de un objeto no válido. 2516095
# Error: se intentó acceder a un atributo de un objeto no válido. 2336850
# Error: se intentó acceder a un atributo de un objeto no válido. 2471588
# Error: se intentó acceder a un atributo de un objeto no válido. 2327347
# Error: se intentó acceder a un atributo de un objeto no válido. 2404792
# Error: se intentó acceder a un atributo de un objeto no válido. 2357200
# Error: se intentó acceder a un atributo de un objeto no válido. 2449651
# Error: se intentó acceder a un atributo de un objeto no válido. 2437857
# Error: se intentó acceder a un atributo de un objeto no válido. 2434999
# Error: se intentó acceder a un atributo de un objeto no válido. 1732651
# Error: se intentó acceder a un atributo de un objeto no válido. 1732651
# Error: se intentó acceder a un atributo de un objeto no válido. 2412472
# Error: se intentó acceder a un atributo de un objeto no válido. 2430791
# Error: se intentó acceder a un atributo de un objeto no válido. 2383259
# Error: se intentó acceder a un atributo de un objeto no válido. 2423664
# Error: se intentó acceder a un atributo de un objeto no válido. 2423664
# Error: se intentó acceder a un atributo de un objeto no válido. 2022741
# Error: se intentó acceder a un atributo de un objeto no válido. 2437117
# Error: se intentó acceder a un atributo de un objeto no válido. 2336923
# Error: se intentó acceder a un atributo de un objeto no válido. 2390759
# Error: se intentó acceder a un atributo de un objeto no válido. 2329119
# Error: se intentó acceder a un atributo de un objeto no válido. 2373342
# Error: se intentó acceder a un atributo de un objeto no válido. 2469166
# Error: se intentó acceder a un atributo de un objeto no válido. 2109283
# Error: se intentó acceder a un atributo de un objeto no válido. 2109283
# Error: se intentó acceder a un atributo de un objeto no válido. 2341002
# Error: se intentó acceder a un atributo de un objeto no válido. 2397476
# Error: se intentó acceder a un atributo de un objeto no válido. 2426549
# Error: se intentó acceder a un atributo de un objeto no válido. 2286329
# Error: se intentó acceder a un atributo de un objeto no válido. 2406355
# Error: se intentó acceder a un atributo de un objeto no válido. 2471468
# Error: se intentó acceder a un atributo de un objeto no válido. 2323301
# Error: se intentó acceder a un atributo de un objeto no válido. 2484443
# Error: se intentó acceder a un atributo de un objeto no válido. 2313457
# Error: se intentó acceder a un atributo de un objeto no válido. 2437201
# Error: se intentó acceder a un atributo de un objeto no válido. 2386829
# Error: se intentó acceder a un atributo de un objeto no válido. 2452282
# Error: se intentó acceder a un atributo de un objeto no válido. 2463655
# Error: se intentó acceder a un atributo de un objeto no válido. 2479930
# Error: se intentó acceder a un atributo de un objeto no válido. 2448726
# Error: se intentó acceder a un atributo de un objeto no válido. 2537467
# Error: se intentó acceder a un atributo de un objeto no válido. 2315316
# Error: se intentó acceder a un atributo de un objeto no válido. 2348869
# Error: se intentó acceder a un atributo de un objeto no válido. 2379395
# Error: se intentó acceder a un atributo de un objeto no válido. 2368413
# Error: se intentó acceder a un atributo de un objeto no válido. 1854655
# Error: se intentó acceder a un atributo de un objeto no válido. 2341106
# Error: se intentó acceder a un atributo de un objeto no válido. 2339474
# Error: se intentó acceder a un atributo de un objeto no válido. 2320090
# Error: se intentó acceder a un atributo de un objeto no válido. 2327403
# Error: se intentó acceder a un atributo de un objeto no válido. 2403625
# Error: se intentó acceder a un atributo de un objeto no válido. 2446304
# Error: se intentó acceder a un atributo de un objeto no válido. 2484564
# Error: se intentó acceder a un atributo de un objeto no válido. 2543465
# Error: se intentó acceder a un atributo de un objeto no válido. 2357594
# Error: se intentó acceder a un atributo de un objeto no válido. 2315236
# Error: se intentó acceder a un atributo de un objeto no válido. 2456747
# Error: se intentó acceder a un atributo de un objeto no válido. 2375531
# Error: se intentó acceder a un atributo de un objeto no válido. 1738152
# Error: se intentó acceder a un atributo de un objeto no válido. 2307856
# Error: se intentó acceder a un atributo de un objeto no válido. 2428718
# Error: se intentó acceder a un atributo de un objeto no válido. 2428718
# Error: se intentó acceder a un atributo de un objeto no válido. 2001521
# Error: se intentó acceder a un atributo de un objeto no válido. 2513406
# Error: se intentó acceder a un atributo de un objeto no válido. 1598077
# Error: se intentó acceder a un atributo de un objeto no válido. 2417511
# Error: se intentó acceder a un atributo de un objeto no válido. 2394056
# Error: se intentó acceder a un atributo de un objeto no válido. 2410944
# Error: se intentó acceder a un atributo de un objeto no válido. 2129789
# Error: se intentó acceder a un atributo de un objeto no válido. 2383130
# Error: se intentó acceder a un atributo de un objeto no válido. 2356901
# Error: se intentó acceder a un atributo de un objeto no válido. 2052549
# Error: se intentó acceder a un atributo de un objeto no válido. 2404323
# Error: se intentó acceder a un atributo de un objeto no válido. 2392802
# Error: se intentó acceder a un atributo de un objeto no válido. 2377677
# Error: se intentó acceder a un atributo de un objeto no válido. 2442227
# Error: se intentó acceder a un atributo de un objeto no válido. 2442227
# Error: se intentó acceder a un atributo de un objeto no válido. 2357841
# Error: se intentó acceder a un atributo de un objeto no válido. 2254610
# Error: se intentó acceder a un atributo de un objeto no válido. 2468758
# Error: se intentó acceder a un atributo de un objeto no válido. 2445444
# Error: se intentó acceder a un atributo de un objeto no válido. 2308083
# Error: se intentó acceder a un atributo de un objeto no válido. 1986183
# Error: se intentó acceder a un atributo de un objeto no válido. 2360445
# Error: se intentó acceder a un atributo de un objeto no válido. 2361688
# Error: se intentó acceder a un atributo de un objeto no válido. 2426354
# Error: se intentó acceder a un atributo de un objeto no válido. 2364562
# Error: se intentó acceder a un atributo de un objeto no válido. 2391169
# Error: se intentó acceder a un atributo de un objeto no válido. 2408445
# Error: se intentó acceder a un atributo de un objeto no válido. 2365091
# Error: se intentó acceder a un atributo de un objeto no válido. 2402976
# Error: se intentó acceder a un atributo de un objeto no válido. 2411855
# Error: se intentó acceder a un atributo de un objeto no válido. 1272444
# Error: se intentó acceder a un atributo de un objeto no válido. 2384223
# Error: se intentó acceder a un atributo de un objeto no válido. 2334842
# Error: se intentó acceder a un atributo de un objeto no válido. 2182827
# Error: se intentó acceder a un atributo de un objeto no válido. 1580409
# Error: se intentó acceder a un atributo de un objeto no válido. 2378668
# Error: se intentó acceder a un atributo de un objeto no válido. 2476612
# Error: se intentó acceder a un atributo de un objeto no válido. 2439198
# Error: se intentó acceder a un atributo de un objeto no válido. 2360131
# Error: se intentó acceder a un atributo de un objeto no válido. 2265338
# Error: se intentó acceder a un atributo de un objeto no válido. 2426366
# Error: se intentó acceder a un atributo de un objeto no válido. 2421291
# Error: se intentó acceder a un atributo de un objeto no válido. 2316283
# Error: se intentó acceder a un atributo de un objeto no válido. 1953124
# Error: se intentó acceder a un atributo de un objeto no válido. 2412194
# Error: se intentó acceder a un atributo de un objeto no válido. 2326274
# Error: se intentó acceder a un atributo de un objeto no válido. 2490234
# Error: se intentó acceder a un atributo de un objeto no válido. 2425678
# Error: se intentó acceder a un atributo de un objeto no válido. 2334579
# Error: se intentó acceder a un atributo de un objeto no válido. 1934190
# Error: se intentó acceder a un atributo de un objeto no válido. 2000565
# Error: se intentó acceder a un atributo de un objeto no válido. 2341111
# Error: se intentó acceder a un atributo de un objeto no válido. 2337145
# Error: se intentó acceder a un atributo de un objeto no válido. 2351799
# Error: se intentó acceder a un atributo de un objeto no válido. 2354528
# Error: se intentó acceder a un atributo de un objeto no válido. 2390106
# Error: se intentó acceder a un atributo de un objeto no válido. 2480517
# Error: se intentó acceder a un atributo de un objeto no válido. 1566321
# Error: se intentó acceder a un atributo de un objeto no válido. 2327769
# Error: se intentó acceder a un atributo de un objeto no válido. 1871044
# Error: se intentó acceder a un atributo de un objeto no válido. 2356875
# Error: se intentó acceder a un atributo de un objeto no válido. 2351887
# Error: se intentó acceder a un atributo de un objeto no válido. 2353135
# Error: se intentó acceder a un atributo de un objeto no válido. 2353135
# Error: se intentó acceder a un atributo de un objeto no válido. 2325847
# Error: se intentó acceder a un atributo de un objeto no válido. 2408376
# Error: se intentó acceder a un atributo de un objeto no válido. 2342140
# Error: se intentó acceder a un atributo de un objeto no válido. 2422351
# Error: se intentó acceder a un atributo de un objeto no válido. 2329565
# Error: se intentó acceder a un atributo de un objeto no válido. 2314484
# Error: se intentó acceder a un atributo de un objeto no válido. 2326417
# Error: se intentó acceder a un atributo de un objeto no válido. 2468165
# Error: se intentó acceder a un atributo de un objeto no válido. 2468165
# Error: se intentó acceder a un atributo de un objeto no válido. 2417409
# Error: se intentó acceder a un atributo de un objeto no válido. 1735262
# Error: se intentó acceder a un atributo de un objeto no válido. 2319601
# Error: se intentó acceder a un atributo de un objeto no válido. 2316181
# Error: se intentó acceder a un atributo de un objeto no válido. 1987814
# Error: se intentó acceder a un atributo de un objeto no válido. 2385346
# Error: se intentó acceder a un atributo de un objeto no válido. 2435103
# Error: se intentó acceder a un atributo de un objeto no válido. 2341039
# Error: se intentó acceder a un atributo de un objeto no válido. 2373936
# Error: se intentó acceder a un atributo de un objeto no válido. 2422794
# Error: se intentó acceder a un atributo de un objeto no válido. 2425295
# Error: se intentó acceder a un atributo de un objeto no válido. 2391524
# Error: se intentó acceder a un atributo de un objeto no válido. 2408370
# Error: se intentó acceder a un atributo de un objeto no válido. 2432151
# Error: se intentó acceder a un atributo de un objeto no válido. 2312848
# Error: se intentó acceder a un atributo de un objeto no válido. 2436720
# Error: se intentó acceder a un atributo de un objeto no válido. 2411902
# Error: se intentó acceder a un atributo de un objeto no válido. 1955516
# Error: se intentó acceder a un atributo de un objeto no válido. 1836806
# Error: se intentó acceder a un atributo de un objeto no válido. 2429440
# Error: se intentó acceder a un atributo de un objeto no válido. 2386845
# Error: se intentó acceder a un atributo de un objeto no válido. 2459399
# Error: se intentó acceder a un atributo de un objeto no válido. 1696824
# Error: se intentó acceder a un atributo de un objeto no válido. 2367289
# Error: se intentó acceder a un atributo de un objeto no válido. 2337298
# Error: se intentó acceder a un atributo de un objeto no válido. 2461417
# Error: se intentó acceder a un atributo de un objeto no válido. 2362619
# Error: se intentó acceder a un atributo de un objeto no válido. 2477937
# Error: se intentó acceder a un atributo de un objeto no válido. 2516547
# Error: se intentó acceder a un atributo de un objeto no válido. 1646954
# Error: se intentó acceder a un atributo de un objeto no válido. 2325631
# Error: se intentó acceder a un atributo de un objeto no válido. 2325631
# Error: se intentó acceder a un atributo de un objeto no válido. 2327716
# Error: se intentó acceder a un atributo de un objeto no válido. 2427359
# Error: se intentó acceder a un atributo de un objeto no válido. 2339465
# Error: se intentó acceder a un atributo de un objeto no válido. 2340272
# Error: se intentó acceder a un atributo de un objeto no válido. 2313480
# Error: se intentó acceder a un atributo de un objeto no válido. 2442440
# Error: se intentó acceder a un atributo de un objeto no válido. 2390753
# Error: se intentó acceder a un atributo de un objeto no válido. 2474044
# Error: se intentó acceder a un atributo de un objeto no válido. 2338690
# Error: se intentó acceder a un atributo de un objeto no válido. 2350485
# Error: se intentó acceder a un atributo de un objeto no válido. 2500318
# Error: se intentó acceder a un atributo de un objeto no válido. 2436052
# Error: se intentó acceder a un atributo de un objeto no válido. 1594247
# Error: se intentó acceder a un atributo de un objeto no válido. 2113760
# Error: se intentó acceder a un atributo de un objeto no válido. 2388168
# Error: se intentó acceder a un atributo de un objeto no válido. 2388168
# Error: se intentó acceder a un atributo de un objeto no válido. 2374765
# Error: se intentó acceder a un atributo de un objeto no válido. 2437387
# Error: se intentó acceder a un atributo de un objeto no válido. 2320005
# Error: se intentó acceder a un atributo de un objeto no válido. 2368731
# Error: se intentó acceder a un atributo de un objeto no válido. 2357534
# Error: se intentó acceder a un atributo de un objeto no válido. 2351980
# Error: se intentó acceder a un atributo de un objeto no válido. 2531637
# Error: se intentó acceder a un atributo de un objeto no válido. 2423889
# Error: se intentó acceder a un atributo de un objeto no válido. 2360406
# Error: se intentó acceder a un atributo de un objeto no válido. 2360406
# Error: se intentó acceder a un atributo de un objeto no válido. 2403363
# Error: se intentó acceder a un atributo de un objeto no válido. 2318798
# Error: se intentó acceder a un atributo de un objeto no válido. 1975156
# Error: se intentó acceder a un atributo de un objeto no válido. 1975156
# Error: se intentó acceder a un atributo de un objeto no válido. 2360047
# Error: se intentó acceder a un atributo de un objeto no válido. 2360047
# Error: se intentó acceder a un atributo de un objeto no válido. 2314635
# Error: se intentó acceder a un atributo de un objeto no válido. 2484037
# Error: se intentó acceder a un atributo de un objeto no válido. 2311809
# Error: se intentó acceder a un atributo de un objeto no válido. 2340921
# Error: se intentó acceder a un atributo de un objeto no válido. 2429151
# Error: se intentó acceder a un atributo de un objeto no válido. 2329094
# Error: se intentó acceder a un atributo de un objeto no válido. 2394921
# Error: se intentó acceder a un atributo de un objeto no válido. 2404876
# Error: se intentó acceder a un atributo de un objeto no válido. 1713532
# Error: se intentó acceder a un atributo de un objeto no válido. 2309766
# Error: se intentó acceder a un atributo de un objeto no válido. 1757277
# Error: se intentó acceder a un atributo de un objeto no válido. 2513772
# Error: se intentó acceder a un atributo de un objeto no válido. 2356296
# Error: se intentó acceder a un atributo de un objeto no válido. 2510471
# Error: se intentó acceder a un atributo de un objeto no válido. 2267787
# Error: se intentó acceder a un atributo de un objeto no válido. 1709076
# Error: se intentó acceder a un atributo de un objeto no válido. 1709076
# Error: se intentó acceder a un atributo de un objeto no válido. 2463068
# Error: se intentó acceder a un atributo de un objeto no válido. 2454121
# Error: se intentó acceder a un atributo de un objeto no válido. 2139973
# Error: se intentó acceder a un atributo de un objeto no válido. 2358292
# Error: se intentó acceder a un atributo de un objeto no válido. 2449343
# Error: se intentó acceder a un atributo de un objeto no válido. 2313520
# Error: se intentó acceder a un atributo de un objeto no válido. 2318473
# Error: se intentó acceder a un atributo de un objeto no válido. 2401925
# Error: se intentó acceder a un atributo de un objeto no válido. 2362362
# Error: se intentó acceder a un atributo de un objeto no válido. 2362072
# Error: se intentó acceder a un atributo de un objeto no válido. 2478493
# Error: se intentó acceder a un atributo de un objeto no válido. 2308805
# Error: se intentó acceder a un atributo de un objeto no válido. 2338422
# Error: se intentó acceder a un atributo de un objeto no válido. 2359161
# Error: se intentó acceder a un atributo de un objeto no válido. 1728165
# Error: se intentó acceder a un atributo de un objeto no válido. 1728165
# Error: se intentó acceder a un atributo de un objeto no válido. 2336670
# Error: se intentó acceder a un atributo de un objeto no válido. 2466591
# Error: se intentó acceder a un atributo de un objeto no válido. 2448028
# Error: se intentó acceder a un atributo de un objeto no válido. 2238059
# Error: se intentó acceder a un atributo de un objeto no válido. 2447342
# Error: se intentó acceder a un atributo de un objeto no válido. 2447342
# Error: se intentó acceder a un atributo de un objeto no válido. 2266002
# Error: se intentó acceder a un atributo de un objeto no válido. 2415003
# Error: se intentó acceder a un atributo de un objeto no válido. 2415003
# Error: se intentó acceder a un atributo de un objeto no válido. 2290382
# Error: se intentó acceder a un atributo de un objeto no válido. 2359069
# Error: se intentó acceder a un atributo de un objeto no válido. 2375044
# Error: se intentó acceder a un atributo de un objeto no válido. 2475176
# Error: se intentó acceder a un atributo de un objeto no válido. 2370642
# Error: se intentó acceder a un atributo de un objeto no válido. 2464207
# Error: se intentó acceder a un atributo de un objeto no válido. 2391189
# Error: se intentó acceder a un atributo de un objeto no válido. 2460484
# Error: se intentó acceder a un atributo de un objeto no válido. 1869044
# Error: se intentó acceder a un atributo de un objeto no válido. 2403479
# Error: se intentó acceder a un atributo de un objeto no válido. 2350861
# Error: se intentó acceder a un atributo de un objeto no válido. 2374790
# Error: se intentó acceder a un atributo de un objeto no válido. 2496578
# Error: se intentó acceder a un atributo de un objeto no válido. 2442504
# Error: se intentó acceder a un atributo de un objeto no válido. 2347670
# Error: se intentó acceder a un atributo de un objeto no válido. 2346170
# Error: se intentó acceder a un atributo de un objeto no válido. 2436079
# Error: se intentó acceder a un atributo de un objeto no válido. 2417975
# Error: se intentó acceder a un atributo de un objeto no válido. 2378350
# Error: se intentó acceder a un atributo de un objeto no válido. 2378350
# Error: se intentó acceder a un atributo de un objeto no válido. 1895050
# Error: se intentó acceder a un atributo de un objeto no válido. 2456905
# Error: se intentó acceder a un atributo de un objeto no válido. 2441679
# Error: se intentó acceder a un atributo de un objeto no válido. 2336671
# Error: se intentó acceder a un atributo de un objeto no válido. 2353585
# Error: se intentó acceder a un atributo de un objeto no válido. 2316200
# Error: se intentó acceder a un atributo de un objeto no válido. 2347920
# Error: se intentó acceder a un atributo de un objeto no válido. 2388232
# Error: se intentó acceder a un atributo de un objeto no válido. 2388232
# Error: se intentó acceder a un atributo de un objeto no válido. 2305325
# Error: se intentó acceder a un atributo de un objeto no válido. 2449986
# Error: se intentó acceder a un atributo de un objeto no válido. 2460140
# Error: se intentó acceder a un atributo de un objeto no válido. 2460140
# Error: se intentó acceder a un atributo de un objeto no válido. 2319532
# Error: se intentó acceder a un atributo de un objeto no válido. 2356824
# Error: se intentó acceder a un atributo de un objeto no válido. 1977448
# Error: se intentó acceder a un atributo de un objeto no válido. 1977448
# Error: se intentó acceder a un atributo de un objeto no válido. 2011410
# Error: se intentó acceder a un atributo de un objeto no válido. 2387416
# Error: se intentó acceder a un atributo de un objeto no válido. 2472875
# Error: se intentó acceder a un atributo de un objeto no válido. 2322489
# Error: se intentó acceder a un atributo de un objeto no válido. 2449726
# Error: se intentó acceder a un atributo de un objeto no válido. 2486519
# Error: se intentó acceder a un atributo de un objeto no válido. 2201188
# Error: se intentó acceder a un atributo de un objeto no válido. 2332503
# Error: se intentó acceder a un atributo de un objeto no válido. 2427810
# Error: se intentó acceder a un atributo de un objeto no válido. 2237202
# Error: se intentó acceder a un atributo de un objeto no válido. 2292771
# Error: se intentó acceder a un atributo de un objeto no válido. 2326905
# Error: se intentó acceder a un atributo de un objeto no válido. 2370646
# Error: se intentó acceder a un atributo de un objeto no válido. 2422261
# Error: se intentó acceder a un atributo de un objeto no válido. 2079016
# Error: se intentó acceder a un atributo de un objeto no válido. 2267185
# Error: se intentó acceder a un atributo de un objeto no válido. 2389643
# Error: se intentó acceder a un atributo de un objeto no válido. 2330706
# Error: se intentó acceder a un atributo de un objeto no válido. 2557941
# Error: se intentó acceder a un atributo de un objeto no válido. 2445055
# Error: se intentó acceder a un atributo de un objeto no válido. 2350819
# Error: se intentó acceder a un atributo de un objeto no válido. 2351454
# Error: se intentó acceder a un atributo de un objeto no válido. 2351454
# Error: se intentó acceder a un atributo de un objeto no válido. 2354114
# Error: se intentó acceder a un atributo de un objeto no válido. 2397916
# Error: se intentó acceder a un atributo de un objeto no válido. 2418059
# Error: se intentó acceder a un atributo de un objeto no válido. 2353755
# Error: se intentó acceder a un atributo de un objeto no válido. 2182517
# Error: se intentó acceder a un atributo de un objeto no válido. 2392541
# Error: se intentó acceder a un atributo de un objeto no válido. 2406401
# Error: se intentó acceder a un atributo de un objeto no válido. 2406401
# Error: se intentó acceder a un atributo de un objeto no válido. 2321446
# Error: se intentó acceder a un atributo de un objeto no válido. 2333781
# Error: se intentó acceder a un atributo de un objeto no válido. 2484517
# Error: se intentó acceder a un atributo de un objeto no válido. 2370299
# Error: se intentó acceder a un atributo de un objeto no válido. 2371182
# Error: se intentó acceder a un atributo de un objeto no válido. 2445040
# Error: se intentó acceder a un atributo de un objeto no válido. 2423127
# Error: se intentó acceder a un atributo de un objeto no válido. 2374003
# Error: se intentó acceder a un atributo de un objeto no válido. 2323647
# Error: se intentó acceder a un atributo de un objeto no válido. 2340564
# Error: se intentó acceder a un atributo de un objeto no válido. 2417533
# Error: se intentó acceder a un atributo de un objeto no válido. 2460462
# Error: se intentó acceder a un atributo de un objeto no válido. 2420431
# Error: se intentó acceder a un atributo de un objeto no válido. 2391368
# Error: se intentó acceder a un atributo de un objeto no válido. 2536348
# Error: se intentó acceder a un atributo de un objeto no válido. 1801992
# Error: se intentó acceder a un atributo de un objeto no válido. 2157913
# Error: se intentó acceder a un atributo de un objeto no válido. 2313742
# Error: se intentó acceder a un atributo de un objeto no válido. 2465339
# Error: se intentó acceder a un atributo de un objeto no válido. 2353833
# Error: se intentó acceder a un atributo de un objeto no válido. 2333873
# Error: se intentó acceder a un atributo de un objeto no válido. 2316172
# Error: se intentó acceder a un atributo de un objeto no válido. 2486822
# Error: se intentó acceder a un atributo de un objeto no válido. 1808524
# Error: se intentó acceder a un atributo de un objeto no válido. 2441829
# Error: se intentó acceder a un atributo de un objeto no válido. 2388140
# Error: se intentó acceder a un atributo de un objeto no válido. 2432100
# Error: se intentó acceder a un atributo de un objeto no válido. 2389308
# Error: se intentó acceder a un atributo de un objeto no válido. 2342098
# Error: se intentó acceder a un atributo de un objeto no válido. 2358160
# Error: se intentó acceder a un atributo de un objeto no válido. 2454180
# Error: se intentó acceder a un atributo de un objeto no válido. 2315885
# Error: se intentó acceder a un atributo de un objeto no válido. 1839956
# Error: se intentó acceder a un atributo de un objeto no válido. 2323710
# Error: se intentó acceder a un atributo de un objeto no válido. 2394150
# Error: se intentó acceder a un atributo de un objeto no válido. 2398223
# Error: se intentó acceder a un atributo de un objeto no válido. 1632829
# Error: se intentó acceder a un atributo de un objeto no válido. 1978303
# Error: se intentó acceder a un atributo de un objeto no válido. 2326148
# Error: se intentó acceder a un atributo de un objeto no válido. 2388419
# Error: se intentó acceder a un atributo de un objeto no válido. 2449857
# Error: se intentó acceder a un atributo de un objeto no válido. 2435367
# Error: se intentó acceder a un atributo de un objeto no válido. 1796608
# Error: se intentó acceder a un atributo de un objeto no válido. 2354161
# Error: se intentó acceder a un atributo de un objeto no válido. 1744569
# Error: se intentó acceder a un atributo de un objeto no válido. 2413359
# Error: se intentó acceder a un atributo de un objeto no válido. 2497458
# Error: se intentó acceder a un atributo de un objeto no válido. 2339823
# Error: se intentó acceder a un atributo de un objeto no válido. 2485587
# Error: se intentó acceder a un atributo de un objeto no válido. 2367678
# Error: se intentó acceder a un atributo de un objeto no válido. 2316075
# Error: se intentó acceder a un atributo de un objeto no válido. 2417574
# Error: se intentó acceder a un atributo de un objeto no válido. 2333955
# Error: se intentó acceder a un atributo de un objeto no válido. 2391021
# Error: se intentó acceder a un atributo de un objeto no válido. 2322575
# Error: se intentó acceder a un atributo de un objeto no válido. 2438953
# Error: se intentó acceder a un atributo de un objeto no válido. 2386619
# Error: se intentó acceder a un atributo de un objeto no válido. 2473778
# Error: se intentó acceder a un atributo de un objeto no válido. 2401647
# Error: se intentó acceder a un atributo de un objeto no válido. 2402807
# Error: se intentó acceder a un atributo de un objeto no válido. 2392024
# Error: se intentó acceder a un atributo de un objeto no válido. 2403946
# Error: se intentó acceder a un atributo de un objeto no válido. 2416065
# Error: se intentó acceder a un atributo de un objeto no válido. 2538411
# Error: se intentó acceder a un atributo de un objeto no válido. 2337014
# Error: se intentó acceder a un atributo de un objeto no válido. 2343629
# Error: se intentó acceder a un atributo de un objeto no válido. 2425167
# Error: se intentó acceder a un atributo de un objeto no válido. 2366775
# Error: se intentó acceder a un atributo de un objeto no válido. 2349992
# Error: se intentó acceder a un atributo de un objeto no válido. 2327319
# Error: se intentó acceder a un atributo de un objeto no válido. 2340225
# Error: se intentó acceder a un atributo de un objeto no válido. 2429553
# Error: se intentó acceder a un atributo de un objeto no válido. 2284020
# Error: se intentó acceder a un atributo de un objeto no válido. 2483296
# Error: se intentó acceder a un atributo de un objeto no válido. 2367797
# Error: se intentó acceder a un atributo de un objeto no válido. 2435191
# Error: se intentó acceder a un atributo de un objeto no válido. 2454122
# Error: se intentó acceder a un atributo de un objeto no válido. 2459013
# Error: se intentó acceder a un atributo de un objeto no válido. 2424337
# Error: se intentó acceder a un atributo de un objeto no válido. 2364858
# Error: se intentó acceder a un atributo de un objeto no válido. 2355494
# Error: se intentó acceder a un atributo de un objeto no válido. 2321841
# Error: se intentó acceder a un atributo de un objeto no válido. 2307187
# Error: se intentó acceder a un atributo de un objeto no válido. 2415236
# Error: se intentó acceder a un atributo de un objeto no válido. 2394890
# Error: se intentó acceder a un atributo de un objeto no válido. 2229814
# Error: se intentó acceder a un atributo de un objeto no válido. 2313618
# Error: se intentó acceder a un atributo de un objeto no válido. 2406168
# Error: se intentó acceder a un atributo de un objeto no válido. 2313591
# Error: se intentó acceder a un atributo de un objeto no válido. 2382355
# Error: se intentó acceder a un atributo de un objeto no válido. 2282162
# Error: se intentó acceder a un atributo de un objeto no válido. 2359427
# Error: se intentó acceder a un atributo de un objeto no válido. 2394443
# Error: se intentó acceder a un atributo de un objeto no válido. 2343019
# Error: se intentó acceder a un atributo de un objeto no válido. 2360391
# Error: se intentó acceder a un atributo de un objeto no válido. 2387068
# Error: se intentó acceder a un atributo de un objeto no válido. 2348865
# Error: se intentó acceder a un atributo de un objeto no válido. 2402201
# Error: se intentó acceder a un atributo de un objeto no válido. 2349014
# Error: se intentó acceder a un atributo de un objeto no válido. 2476579
# Error: se intentó acceder a un atributo de un objeto no válido. 2325663
# Error: se intentó acceder a un atributo de un objeto no válido. 2379102
# Error: se intentó acceder a un atributo de un objeto no válido. 2364214
# Error: se intentó acceder a un atributo de un objeto no válido. 2369291
# Error: se intentó acceder a un atributo de un objeto no válido. 2003900
# Error: se intentó acceder a un atributo de un objeto no válido. 1892582
# Error: se intentó acceder a un atributo de un objeto no válido. 2316958
# Error: se intentó acceder a un atributo de un objeto no válido. 2354488
# Error: se intentó acceder a un atributo de un objeto no válido. 2484249
# Error: se intentó acceder a un atributo de un objeto no válido. 2473633
# Error: se intentó acceder a un atributo de un objeto no válido. 2369300
# Error: se intentó acceder a un atributo de un objeto no válido. 2320210
# Error: se intentó acceder a un atributo de un objeto no válido. 2372026
# Error: se intentó acceder a un atributo de un objeto no válido. 2541423
# Error: se intentó acceder a un atributo de un objeto no válido. 2481650
# Error: se intentó acceder a un atributo de un objeto no válido. 2419696
# Error: se intentó acceder a un atributo de un objeto no válido. 2454672
# Error: se intentó acceder a un atributo de un objeto no válido. 2434522
# Error: se intentó acceder a un atributo de un objeto no válido. 2434522
# Error: se intentó acceder a un atributo de un objeto no válido. 2324608
# Error: se intentó acceder a un atributo de un objeto no válido. 2296081
# Error: se intentó acceder a un atributo de un objeto no válido. 2309262
# Error: se intentó acceder a un atributo de un objeto no válido. 2347096
# Error: se intentó acceder a un atributo de un objeto no válido. 2129795
# Error: se intentó acceder a un atributo de un objeto no válido. 2227595
# Error: se intentó acceder a un atributo de un objeto no válido. 2509196
# Error: se intentó acceder a un atributo de un objeto no válido. 2356169
# Error: se intentó acceder a un atributo de un objeto no válido. 2301453
# Error: se intentó acceder a un atributo de un objeto no válido. 2442748
# Error: se intentó acceder a un atributo de un objeto no válido. 1651069
# Error: se intentó acceder a un atributo de un objeto no válido. 2453667
# Error: se intentó acceder a un atributo de un objeto no válido. 2324108
# Error: se intentó acceder a un atributo de un objeto no válido. 2405007
# Error: se intentó acceder a un atributo de un objeto no válido. 2330909
# Error: se intentó acceder a un atributo de un objeto no válido. 2477332
# Error: se intentó acceder a un atributo de un objeto no válido. 2490389
# Error: se intentó acceder a un atributo de un objeto no válido. 2404840
# Error: se intentó acceder a un atributo de un objeto no válido. 2331406
# Error: se intentó acceder a un atributo de un objeto no válido. 2479547
# Error: se intentó acceder a un atributo de un objeto no válido. 2447001
# Error: se intentó acceder a un atributo de un objeto no válido. 2390136
# Error: se intentó acceder a un atributo de un objeto no válido. 2306794
# Error: se intentó acceder a un atributo de un objeto no válido. 2306794
# Error: se intentó acceder a un atributo de un objeto no válido. 2314199
# Error: se intentó acceder a un atributo de un objeto no válido. 2318545
# Error: se intentó acceder a un atributo de un objeto no válido. 2433282
# Error: se intentó acceder a un atributo de un objeto no válido. 1940817
# Error: se intentó acceder a un atributo de un objeto no válido. 2303537
# Error: se intentó acceder a un atributo de un objeto no válido. 2325670
# Error: se intentó acceder a un atributo de un objeto no válido. 2424501
# Error: se intentó acceder a un atributo de un objeto no válido. 2424501
# Error: se intentó acceder a un atributo de un objeto no válido. 2016938
# Error: se intentó acceder a un atributo de un objeto no válido. 2328542
# Error: se intentó acceder a un atributo de un objeto no válido. 2413263
# Error: se intentó acceder a un atributo de un objeto no válido. 2423392
# Error: se intentó acceder a un atributo de un objeto no válido. 2317472
# Error: se intentó acceder a un atributo de un objeto no válido. 2418163
# Error: se intentó acceder a un atributo de un objeto no válido. 2322947
# Error: se intentó acceder a un atributo de un objeto no válido. 2430983
# Error: se intentó acceder a un atributo de un objeto no válido. 2345890
# Error: se intentó acceder a un atributo de un objeto no válido. 2430606
# Error: se intentó acceder a un atributo de un objeto no válido. 2418966
# Error: se intentó acceder a un atributo de un objeto no válido. 2357742
# Error: se intentó acceder a un atributo de un objeto no válido. 2314860
# Error: se intentó acceder a un atributo de un objeto no válido. 2451585
# Error: se intentó acceder a un atributo de un objeto no válido. 2340797
# Error: se intentó acceder a un atributo de un objeto no válido. 2502325
# Error: se intentó acceder a un atributo de un objeto no válido. 2498145
# Error: se intentó acceder a un atributo de un objeto no válido. 2399925
# Error: se intentó acceder a un atributo de un objeto no válido. 2356190
# Error: se intentó acceder a un atributo de un objeto no válido. 1905246
# Error: se intentó acceder a un atributo de un objeto no válido. 2240437
# Error: se intentó acceder a un atributo de un objeto no válido. 2379423
# Error: se intentó acceder a un atributo de un objeto no válido. 2339399
# Error: se intentó acceder a un atributo de un objeto no válido. 2339399
# Error: se intentó acceder a un atributo de un objeto no válido. 1651491
# Error: se intentó acceder a un atributo de un objeto no válido. 2343827
# Error: se intentó acceder a un atributo de un objeto no válido. 2410983
# Error: se intentó acceder a un atributo de un objeto no válido. 2313973
# Error: se intentó acceder a un atributo de un objeto no válido. 2137592
# Error: se intentó acceder a un atributo de un objeto no válido. 2410059
# Error: se intentó acceder a un atributo de un objeto no válido. 2357243
# Error: se intentó acceder a un atributo de un objeto no válido. 2214143
# Error: se intentó acceder a un atributo de un objeto no válido. 2401202
# Error: se intentó acceder a un atributo de un objeto no válido. 2474900
# Error: se intentó acceder a un atributo de un objeto no válido. 2492357
# Error: se intentó acceder a un atributo de un objeto no válido. 2327780
# Error: se intentó acceder a un atributo de un objeto no válido. 2343407
# Error: se intentó acceder a un atributo de un objeto no válido. 2494646
# Error: se intentó acceder a un atributo de un objeto no válido. 2247883
# Error: se intentó acceder a un atributo de un objeto no válido. 2360871
# Error: se intentó acceder a un atributo de un objeto no válido. 2493991
# Error: se intentó acceder a un atributo de un objeto no válido. 1680900
# Error: se intentó acceder a un atributo de un objeto no válido. 2324241
# Error: se intentó acceder a un atributo de un objeto no válido. 2413718
# Error: se intentó acceder a un atributo de un objeto no válido. 2432161
# Error: se intentó acceder a un atributo de un objeto no válido. 2318237
# Error: se intentó acceder a un atributo de un objeto no válido. 2405419
# Error: se intentó acceder a un atributo de un objeto no válido. 2356364
# Error: se intentó acceder a un atributo de un objeto no válido. 2376231
# Error: se intentó acceder a un atributo de un objeto no válido. 2354671
# Error: se intentó acceder a un atributo de un objeto no válido. 2400169
# Error: se intentó acceder a un atributo de un objeto no válido. 2032971
# Error: se intentó acceder a un atributo de un objeto no válido. 2375089
# Error: se intentó acceder a un atributo de un objeto no válido. 2447178
# Error: se intentó acceder a un atributo de un objeto no válido. 2509843
# Error: se intentó acceder a un atributo de un objeto no válido. 2313274
# Error: se intentó acceder a un atributo de un objeto no válido. 2411692
# Error: se intentó acceder a un atributo de un objeto no válido. 2321291
# Error: se intentó acceder a un atributo de un objeto no válido. 2452630
# Error: se intentó acceder a un atributo de un objeto no válido. 2540409
# Error: se intentó acceder a un atributo de un objeto no válido. 2484580
# Error: se intentó acceder a un atributo de un objeto no válido. 2332242
# Error: se intentó acceder a un atributo de un objeto no válido. 1749451
# Error: se intentó acceder a un atributo de un objeto no válido. 2192996
# Error: se intentó acceder a un atributo de un objeto no válido. 2424377
# Error: se intentó acceder a un atributo de un objeto no válido. 2321965
# Error: se intentó acceder a un atributo de un objeto no válido. 2317002
# Error: se intentó acceder a un atributo de un objeto no válido. 1662379
# Error: se intentó acceder a un atributo de un objeto no válido. 2388026
# Error: se intentó acceder a un atributo de un objeto no válido. 2322031
# Error: se intentó acceder a un atributo de un objeto no válido. 2453269
# Error: se intentó acceder a un atributo de un objeto no válido. 2314433
# Error: se intentó acceder a un atributo de un objeto no válido. 2454003
# Error: se intentó acceder a un atributo de un objeto no válido. 2470223
# Error: se intentó acceder a un atributo de un objeto no válido. 2460298
# Error: se intentó acceder a un atributo de un objeto no válido. 2342827
# Error: se intentó acceder a un atributo de un objeto no válido. 2314233
# Error: se intentó acceder a un atributo de un objeto no válido. 2346969
# Error: se intentó acceder a un atributo de un objeto no válido. 2335837
# Error: se intentó acceder a un atributo de un objeto no válido. 2324005
# Error: se intentó acceder a un atributo de un objeto no válido. 2412529
# Error: se intentó acceder a un atributo de un objeto no válido. 1791967
# Error: se intentó acceder a un atributo de un objeto no válido. 2399007
# Error: se intentó acceder a un atributo de un objeto no válido. 2397115
# Error: se intentó acceder a un atributo de un objeto no válido. 2233869
# Error: se intentó acceder a un atributo de un objeto no válido. 2334081
# Error: se intentó acceder a un atributo de un objeto no válido. 2334081
# Error: se intentó acceder a un atributo de un objeto no válido. 1856900
# Error: se intentó acceder a un atributo de un objeto no válido. 2392664
# Error: se intentó acceder a un atributo de un objeto no válido. 2362774
# Error: se intentó acceder a un atributo de un objeto no válido. 2530141
# Error: se intentó acceder a un atributo de un objeto no válido. 2330218
# Error: se intentó acceder a un atributo de un objeto no válido. 2330218
# Error: se intentó acceder a un atributo de un objeto no válido. 2097281
# Error: se intentó acceder a un atributo de un objeto no válido. 2150143
# Error: se intentó acceder a un atributo de un objeto no válido. 2349603
# Error: se intentó acceder a un atributo de un objeto no válido. 2397974
# Error: se intentó acceder a un atributo de un objeto no válido. 2464615
# Error: se intentó acceder a un atributo de un objeto no válido. 2433666
# Error: se intentó acceder a un atributo de un objeto no válido. 2429547
# Error: se intentó acceder a un atributo de un objeto no válido. 2332150
# Error: se intentó acceder a un atributo de un objeto no válido. 2332623
# Error: se intentó acceder a un atributo de un objeto no válido. 2511934
# Error: se intentó acceder a un atributo de un objeto no válido. 2403717
# Error: se intentó acceder a un atributo de un objeto no válido. 2462444
# Error: se intentó acceder a un atributo de un objeto no válido. 2170179
# Error: se intentó acceder a un atributo de un objeto no válido. 2338487
# Error: se intentó acceder a un atributo de un objeto no válido. 2337658
# Error: se intentó acceder a un atributo de un objeto no válido. 2438941
# Error: se intentó acceder a un atributo de un objeto no válido. 1894092
# Error: se intentó acceder a un atributo de un objeto no válido. 1827362
# Error: se intentó acceder a un atributo de un objeto no válido. 1879561
# Error: se intentó acceder a un atributo de un objeto no válido. 2423149
# Error: se intentó acceder a un atributo de un objeto no válido. 2323165
# Error: se intentó acceder a un atributo de un objeto no válido. 2500858
# Error: se intentó acceder a un atributo de un objeto no válido. 2334114
# Error: se intentó acceder a un atributo de un objeto no válido. 2446395
# Error: se intentó acceder a un atributo de un objeto no válido. 2322418
# Error: se intentó acceder a un atributo de un objeto no válido. 2348320
# Error: se intentó acceder a un atributo de un objeto no válido. 1699929
# Error: se intentó acceder a un atributo de un objeto no válido. 2392246
# Error: se intentó acceder a un atributo de un objeto no válido. 2392246
# Error: se intentó acceder a un atributo de un objeto no válido. 2413746
# Error: se intentó acceder a un atributo de un objeto no válido. 2102609
# Error: se intentó acceder a un atributo de un objeto no válido. 2403124
# Error: se intentó acceder a un atributo de un objeto no válido. 1989143
# Error: se intentó acceder a un atributo de un objeto no válido. 2432009
# Error: se intentó acceder a un atributo de un objeto no válido. 2487496
# Error: se intentó acceder a un atributo de un objeto no válido. 2487496
# Error: se intentó acceder a un atributo de un objeto no válido. 2342365
# Error: se intentó acceder a un atributo de un objeto no válido. 2336516
# Error: se intentó acceder a un atributo de un objeto no válido. 2435058
# Error: se intentó acceder a un atributo de un objeto no válido. 2493109
# Error: se intentó acceder a un atributo de un objeto no válido. 2263791
# Error: se intentó acceder a un atributo de un objeto no válido. 2425351
# Error: se intentó acceder a un atributo de un objeto no válido. 2411159
# Error: se intentó acceder a un atributo de un objeto no válido. 2328115
# Error: se intentó acceder a un atributo de un objeto no válido. 2360418
# Error: se intentó acceder a un atributo de un objeto no válido. 2439608
# Error: se intentó acceder a un atributo de un objeto no válido. 2367138
# Error: se intentó acceder a un atributo de un objeto no válido. 2363062
# Error: se intentó acceder a un atributo de un objeto no válido. 2484853
# Error: se intentó acceder a un atributo de un objeto no válido. 2343090
# Error: se intentó acceder a un atributo de un objeto no válido. 2345027
# Error: se intentó acceder a un atributo de un objeto no válido. 2462041
# Error: se intentó acceder a un atributo de un objeto no válido. 2505855
# Error: se intentó acceder a un atributo de un objeto no válido. 2364337
# Error: se intentó acceder a un atributo de un objeto no válido. 2394503
# Error: se intentó acceder a un atributo de un objeto no válido. 2346265
# Error: se intentó acceder a un atributo de un objeto no válido. 1760166
# Error: se intentó acceder a un atributo de un objeto no válido. 2459811
# Error: se intentó acceder a un atributo de un objeto no válido. 1946775
# Error: se intentó acceder a un atributo de un objeto no válido. 2351748
# Error: se intentó acceder a un atributo de un objeto no válido. 2356438
# Error: se intentó acceder a un atributo de un objeto no válido. 2511215
# Error: se intentó acceder a un atributo de un objeto no válido. 2025240
# Error: se intentó acceder a un atributo de un objeto no válido. 2454745
# Error: se intentó acceder a un atributo de un objeto no válido. 2378992
# Error: se intentó acceder a un atributo de un objeto no válido. 1612318
# Error: se intentó acceder a un atributo de un objeto no válido. 1864187
# Error: se intentó acceder a un atributo de un objeto no válido. 2478761
# Error: se intentó acceder a un atributo de un objeto no válido. 2309504
# Error: se intentó acceder a un atributo de un objeto no válido. 2419305
# Error: se intentó acceder a un atributo de un objeto no válido. 1748979
# Error: se intentó acceder a un atributo de un objeto no válido. 1748979
# Error: se intentó acceder a un atributo de un objeto no válido. 2439678
# Error: se intentó acceder a un atributo de un objeto no válido. 2355398
# Error: se intentó acceder a un atributo de un objeto no válido. 2321452
# Error: se intentó acceder a un atributo de un objeto no válido. 2337222
# Error: se intentó acceder a un atributo de un objeto no válido. 2317965
# Error: se intentó acceder a un atributo de un objeto no válido. 2333852
# Error: se intentó acceder a un atributo de un objeto no válido. 2312370
# Error: se intentó acceder a un atributo de un objeto no válido. 2403442
# Error: se intentó acceder a un atributo de un objeto no válido. 2453898
# Error: se intentó acceder a un atributo de un objeto no válido. 2312927
# Error: se intentó acceder a un atributo de un objeto no válido. 2397806
# Error: se intentó acceder a un atributo de un objeto no válido. 2447362
# Error: se intentó acceder a un atributo de un objeto no válido. 2431867
# Error: se intentó acceder a un atributo de un objeto no válido. 1687156
# Error: se intentó acceder a un atributo de un objeto no válido. 2323825
# Error: se intentó acceder a un atributo de un objeto no válido. 1753337
# Error: se intentó acceder a un atributo de un objeto no válido. 2320285
# Error: se intentó acceder a un atributo de un objeto no válido. 2450391
# Error: se intentó acceder a un atributo de un objeto no válido. 1881866
# Error: se intentó acceder a un atributo de un objeto no válido. 2345436
# Error: se intentó acceder a un atributo de un objeto no válido. 2397933
# Error: se intentó acceder a un atributo de un objeto no válido. 2434212
# Error: se intentó acceder a un atributo de un objeto no válido. 2434212
# Error: se intentó acceder a un atributo de un objeto no válido. 2449582
# Error: se intentó acceder a un atributo de un objeto no válido. 2349164
# Error: se intentó acceder a un atributo de un objeto no válido. 2363668
# Proceso terminado.
#      El dataset de Participantes_Proveedores tiene el siguiente tamaño: (files x columnas)
# (15051, 8)
#
#
# Se ha registrado los siguientes registros con errores: 881

# %% [markdown]
# ## 4.4 Comprador (Origen: Parties + Buyer)
#
# *** **FALTAN CAMPOS POR IDENTIFICAR EN EL ESQUEMA** ***
# **LLAMADA A SAMPLE**

# %%
# Consulta actualizada a la base de datos Contratos_EDCA
consulta_actualizada = db['Contratos_EDCA_Sample'].find({}, {})

# Creando una lista de diccionarios para facilitar la creación del dataframe
datos = []
Bugs = []
for contrato in consulta_actualizada:
    try:
        comprador = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            'cve_contrato': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'), #award id
            #'identifier_id_inst': 
            'roles': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('roles', 'NA')[0],
            'name': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('name', 'NA'),
            'identifier_legal_name': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('identifier', 'NA').get('legalName', 'NA'),
            #identifier_scheme: contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('identifier', 'NA').get('identifierScheme', 'NA'),
            'identifier_uri': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('identifier', 'NA').get('uri', 'NA'),
            'addres_country_name': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', 'NA').get('countryName', 'NA'),
            'addres_locality': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', 'NA').get('locality', 'NA'),
            'address_postalcode': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', 'NA').get('postalCode', 'NA'),
            'address_region': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', 'NA').get('region', 'NA'),
            'addres_streetaddress': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('address', 'NA').get('streetAddress', 'NA'),
            'contact_point_email': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('contactPoint', 'NA').get('email', 'NA'),
            'contact_point_name': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('contactPoint', 'NA').get('name', 'NA'),
            'contact_point_telephone': contrato.get('releases', [{}])[0].get('parties', [{}])[0].get('contactPoint', 'NA').get('telephone', 'NA'),
            
        }
        #print(contrato_dict['cve_expediente'])
        datos.append(comprador)
    except AttributeError:
        Error = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            'cve_contrato': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'), #award id
        }
        Bugs.append(Error)
        print(f"Error: se intentó acceder a un atributo de un objeto no válido. {Error['cve_expediente']}")

# Creando el dataframe de Parties y Errores
df_comprador = pd.DataFrame(datos)
df_Err_comprador = pd.DataFrame(Bugs)

# Exportando el dataframe a un archivo csv
df_comprador.to_csv('../data/Processed/Compradores_sample.csv', index=False)
df_Err_comprador.to_csv('../data/Processed/Compradores_Errors_sample.csv', index=False)
print("Proceso terminado. \n     El dataset de COMPRADORES tiene el siguiente tamaño: (files x columnas)")

print(df_comprador.shape)
print(f"\n\nSe ha registrado los siguientes registros con errores: {df_Err_comprador.shape[0]}")
# Out:
# Proceso terminado.
#      El dataset de COMPRADORES tiene el siguiente tamaño: (files x columnas)
# (15932, 14)
#
#
# Se ha registrado los siguientes registros con errores: 0

# %% [markdown]
# ## 4.5 Documentos_Tender (Tender)
#
# *** **FALTAN VARIABLES DE DOCS** ***
# *** **LLAMADA A SAMPLE** ***

# %%
# Consulta actualizada a la base de datos Contratos_EDCA
consulta_actualizada = db['Contratos_EDCA_Sample'].find({}, {})

# Creando una lista de diccionarios para facilitar la creación del dataframe
datos = []
Bugs = []
for contrato in consulta_actualizada:
    try:
        licitacion = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            
        }
        #print(contrato_dict['cve_expediente'])
        datos.append(licitacion)
    except AttributeError:
        Error = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            'cve_contrato': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'), #award id
        }
        Bugs.append(Error)
        print(f"Error: se intentó acceder a un atributo de un objeto no válido. {Error['cve_expediente']}")

# Creando el dataframe de Parties y Errores
df_docsTender = pd.DataFrame(datos)
df_Err_docsTender = pd.DataFrame(Bugs)

# Exportando el dataframe a un archivo csv
df_docsTender.to_csv('../data/Processed/Docs_Tender_sample.csv', index=False)
df_Err_docsTender.to_csv('../data/Processed/Docs_Tender_Errors_sample.csv', index=False)
print("Proceso terminado. \n     El dataset de DOCS_TENDER tiene el siguiente tamaño: (files x columnas)")

print(df_comprador.shape)
print(f"\n\nSe ha registrado los siguientes registros con errores: {df_Err_docsTender.shape[0]}")
# Out:
# Proceso terminado.
#      El dataset de DOCS_TENDER tiene el siguiente tamaño: (files x columnas)
# (15932, 14)
#
#
# Se ha registrado los siguientes registros con errores: 0

# %% [markdown]
# ## 4.6 ITEMS_ADQ (Origen: Awards)
#
# *** **FALTAN VARIABLES DE DOCS** ***
# *** **LLAMADA A SAMPLE** ***

# %%
# Consulta actualizada a la base de datos Contratos_EDCA
consulta_actualizada = db['Contratos_EDCA_Sample'].find({}, {})

# Creando una lista de diccionarios para facilitar la creación del dataframe
datos = []
Bugs = []
for contrato in consulta_actualizada:
    try:
        licitacion = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            
        }
        #print(contrato_dict['cve_expediente'])
        datos.append(licitacion)
    except AttributeError:
        Error = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            'cve_contrato': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'), #award id
        ### Falta identificar las variables en el esquema.
        }
        Bugs.append(Error)
        print(f"Error: se intentó acceder a un atributo de un objeto no válido. {Error['cve_expediente']}")

# Creando el dataframe de Parties y Errores
df_docsTender = pd.DataFrame(datos)
df_Err_docsTender = pd.DataFrame(Bugs)

# Exportando el dataframe a un archivo csv
df_docsTender.to_csv('../data/Processed/Docs_Tender_sample.csv', index=False)
df_Err_docsTender.to_csv('../data/Processed/Docs_Tender_Errors_sample.csv', index=False)
print("Proceso terminado. \n     El dataset de DOCS_TENDER tiene el siguiente tamaño: (files x columnas)")

print(df_comprador.shape)
print(f"\n\nSe ha registrado los siguientes registros con errores: {df_Err_docsTender.shape[0]}")
# Out:
# Proceso terminado.
#      El dataset de DOCS_TENDER tiene el siguiente tamaño: (files x columnas)
# (15932, 14)
#
#
# Se ha registrado los siguientes registros con errores: 0

# %% [markdown]
# ## 4.7 ITEMS_TENDER (Origen: Tender)
#
# *** **FALTAN VARIABLES DE DOCS** ***
# *** **LLAMADA A SAMPLE** ***

# %%
# Consulta actualizada a la base de datos Contratos_EDCA
consulta_actualizada = db['Contratos_EDCA_Sample'].find({}, {})

# Creando una lista de diccionarios para facilitar la creación del dataframe
datos = []
Bugs = []
for contrato in consulta_actualizada:
    try:
        licitacion = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            # Falta identificar variables
        }
        #print(contrato_dict['cve_expediente'])
        datos.append(licitacion)
    except AttributeError:
        Error = {
            'cve_expediente': contrato.get('releases', [{}])[0].get('tender', {}).get('id', 'NA'), #id
            'cve_contrato': contrato.get('releases', [{}])[0].get('awards', [{}])[0].get('id', 'NA'), #award id
        ### Falta identificar las variables en el esquema.
        }
        Bugs.append(Error)
        print(f"Error: se intentó acceder a un atributo de un objeto no válido. {Error['cve_expediente']}")

# Creando el dataframe de Parties y Errores
df_docsTender = pd.DataFrame(datos)
df_Err_docsTender = pd.DataFrame(Bugs)

# Exportando el dataframe a un archivo csv
df_docsTender.to_csv('../data/Processed/Docs_Tender_sample.csv', index=False)
df_Err_docsTender.to_csv('../data/Processed/Docs_Tender_Errors_sample.csv', index=False)
print("Proceso terminado. \n     El dataset de DOCS_TENDER tiene el siguiente tamaño: (files x columnas)")

print(df_comprador.shape)
print(f"\n\nSe ha registrado los siguientes registros con errores: {df_Err_docsTender.shape[0]}")
# Out:
# Proceso terminado.
#      El dataset de DOCS_TENDER tiene el siguiente tamaño: (files x columnas)
# (15932, 14)
#
#
# Se ha registrado los siguientes registros con errores: 0
